# %%
import cv2
import numpy as np
from ultralytics import YOLO
from filterpy.kalman import KalmanFilter

def predict_future_positions(kf, steps=35):
    future_positions = []
    state = kf.x.copy()
    for _ in range(steps):
        state = np.dot(kf.F, state)
        future_positions.append((int(state[0]), int(state[1])))
    return future_positions

model_path = "/Users/Aleksander/Desktop/видео/best.pt"
model = YOLO(model_path)

# Настройка фильтра Калмана
kf = KalmanFilter(dim_x=4, dim_z=2)
kf.F = np.array([[1, 0, 1, 0],
                 [0, 1, 0, 1],
                 [0, 0, 1, 0],
                 [0, 0, 0, 1]])
kf.H = np.array([[1, 0, 0, 0],
                 [0, 1, 0, 0]])
kf.P *= 1000
kf.R = np.array([[10, 0], [0, 10]])
kf.Q *= 0.1

video_path = "/Users/Aleksander/Desktop/видео/IMG_9269.mp4"
output_video_path = "/Users/Aleksander/Desktop/видео/output_video_with_tracking.mp4"

# Открытие видео
cap = cv2.VideoCapture(video_path)

fps = int(cap.get(cv2.CAP_PROP_FPS))
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fourcc = cv2.VideoWriter_fourcc(*'mp4v')

out = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))

drone_tracks = []  
max_track_length = 35  

frame_count = 0
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    results = model.predict(source=frame, conf=0.65, iou=0.3)
    annotated_frame = results[0].plot()  # Получаем кадр с bounding boxes от YOLO

    for result in results:
        for box in result.boxes.data:
            x1, y1, x2, y2, conf, cls = box.tolist()
            x_center = (x1 + x2) / 2
            y_center = (y1 + y2) / 2

            # Обновление фильтра Калмана
            kf.predict()
            kf.update([x_center, y_center])
            x_pred, y_pred = kf.x[:2]

            drone_tracks.append((int(x_pred), int(y_pred)))
            if len(drone_tracks) > max_track_length:
                drone_tracks.pop(0)

    # Отрисовка истории перемещения (красная линия)
    for i in range(1, len(drone_tracks)):
        cv2.line(annotated_frame, drone_tracks[i - 1], drone_tracks[i], (0, 0, 255), 2)

    # Предсказание будущих позиций
    future_positions = predict_future_positions(kf, steps=35)

    # Отрисовка предсказанной траектории (синяя линия)
    for i in range(len(future_positions) - 1):
        cv2.line(annotated_frame, future_positions[i], future_positions[i + 1], (255, 0, 0), 2)

    # Сохранение и отображение
    out.write(annotated_frame)
    cv2.imshow("Drone Detection & Tracking", annotated_frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

    frame_count += 1
    print(f"Processed frame {frame_count}")

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 640x352 1 drone, 61.6ms
# Speed: 1.4ms preprocess, 61.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 1
#
# 0: 640x352 (no detections), 45.4ms
# Speed: 1.2ms preprocess, 45.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 2
#
# 0: 640x352 (no detections), 46.5ms
# Speed: 1.2ms preprocess, 46.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 3
# C:\Users\Aleksander\AppData\Local\Temp\ipykernel_3964\359153886.py:65: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   drone_tracks.append((int(x_pred), int(y_pred)))
# C:\Users\Aleksander\AppData\Local\Temp\ipykernel_3964\359153886.py:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   future_positions.append((int(state[0]), int(state[1])))
# 0: 640x352 (no detections), 44.5ms
# Speed: 1.2ms preprocess, 44.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 4
#
# 0: 640x352 (no detections), 46.2ms
# Speed: 1.3ms preprocess, 46.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 5
#
# 0: 640x352 (no detections), 44.9ms
# Speed: 1.2ms preprocess, 44.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 6
#
# 0: 640x352 (no detections), 45.1ms
# Speed: 1.7ms preprocess, 45.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 7
#
# 0: 640x352 (no detections), 47.1ms
# Speed: 1.7ms preprocess, 47.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 8
#
# 0: 640x352 (no detections), 46.7ms
# Speed: 1.2ms preprocess, 46.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 9
#
# 0: 640x352 (no detections), 44.5ms
# Speed: 1.1ms preprocess, 44.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 10
#
# 0: 640x352 (no detections), 44.5ms
# Speed: 1.2ms preprocess, 44.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 11
#
# 0: 640x352 (no detections), 46.5ms
# Speed: 1.2ms preprocess, 46.5ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 12
#
# 0: 640x352 (no detections), 43.6ms
# Speed: 1.1ms preprocess, 43.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 13
#
# 0: 640x352 (no detections), 43.6ms
# Speed: 1.1ms preprocess, 43.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 14
#
# 0: 640x352 (no detections), 48.1ms
# Speed: 1.1ms preprocess, 48.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 15
#
# 0: 640x352 (no detections), 43.1ms
# Speed: 1.3ms preprocess, 43.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 16
#
# 0: 640x352 (no detections), 43.8ms
# Speed: 1.3ms preprocess, 43.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 17
#
# 0: 640x352 (no detections), 43.8ms
# Speed: 1.2ms preprocess, 43.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 18
#
# 0: 640x352 (no detections), 43.0ms
# Speed: 1.4ms preprocess, 43.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 19
#
# 0: 640x352 (no detections), 43.2ms
# Speed: 1.2ms preprocess, 43.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 20
#
# 0: 640x352 (no detections), 43.9ms
# Speed: 1.3ms preprocess, 43.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 21
#
# 0: 640x352 (no detections), 42.7ms
# Speed: 1.3ms preprocess, 42.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 22
#
# 0: 640x352 (no detections), 43.3ms
# Speed: 1.2ms preprocess, 43.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 23
#
# 0: 640x352 (no detections), 42.8ms
# Speed: 1.3ms preprocess, 42.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 24
#
# 0: 640x352 (no detections), 43.6ms
# Speed: 1.2ms preprocess, 43.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 25
#
# 0: 640x352 (no detections), 43.2ms
# Speed: 1.3ms preprocess, 43.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 26
#
# 0: 640x352 1 drone, 43.8ms
# Speed: 1.1ms preprocess, 43.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 27
#
# 0: 640x352 (no detections), 44.1ms
# Speed: 1.1ms preprocess, 44.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 28
#
# 0: 640x352 (no detections), 41.1ms
# Speed: 1.1ms preprocess, 41.1ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 29
#
# 0: 640x352 (no detections), 47.7ms
# Speed: 1.2ms preprocess, 47.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 30
#
# 0: 640x352 (no detections), 43.5ms
# Speed: 1.2ms preprocess, 43.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 31
#
# 0: 640x352 (no detections), 45.0ms
# Speed: 1.1ms preprocess, 45.0ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 32
#
# 0: 640x352 (no detections), 43.8ms
# Speed: 1.2ms preprocess, 43.8ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 33
#
# 0: 640x352 (no detections), 44.3ms
# Speed: 1.1ms preprocess, 44.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 34
#
# 0: 640x352 (no detections), 47.5ms
# Speed: 1.2ms preprocess, 47.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 35
#
# 0: 640x352 (no detections), 41.3ms
# Speed: 1.1ms preprocess, 41.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 36
#
# 0: 640x352 (no detections), 43.6ms
# Speed: 1.1ms preprocess, 43.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 37
#
# 0: 640x352 (no detections), 43.3ms
# Speed: 1.1ms preprocess, 43.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 38
#
# 0: 640x352 (no detections), 47.0ms
# Speed: 1.4ms preprocess, 47.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 39
#
# 0: 640x352 (no detections), 42.3ms
# Speed: 1.6ms preprocess, 42.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 40
#
# 0: 640x352 (no detections), 50.8ms
# Speed: 1.1ms preprocess, 50.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 41
#
# 0: 640x352 (no detections), 42.9ms
# Speed: 1.1ms preprocess, 42.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 42
#
# 0: 640x352 (no detections), 41.3ms
# Speed: 1.2ms preprocess, 41.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 43
#
# 0: 640x352 (no detections), 44.9ms
# Speed: 1.2ms preprocess, 44.9ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 44
#
# 0: 640x352 (no detections), 46.8ms
# Speed: 1.4ms preprocess, 46.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 45
#
# 0: 640x352 (no detections), 43.7ms
# Speed: 1.1ms preprocess, 43.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 46
#
# 0: 640x352 (no detections), 41.1ms
# Speed: 1.1ms preprocess, 41.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 47
#
# 0: 640x352 (no detections), 42.8ms
# Speed: 1.1ms preprocess, 42.8ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 48
#
# 0: 640x352 (no detections), 42.1ms
# Speed: 1.1ms preprocess, 42.1ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 49
#
# 0: 640x352 (no detections), 44.6ms
# Speed: 1.1ms preprocess, 44.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 50
#
# 0: 640x352 (no detections), 58.3ms
# Speed: 2.0ms preprocess, 58.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 51
#
# 0: 640x352 (no detections), 46.9ms
# Speed: 1.4ms preprocess, 46.9ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 52
#
# 0: 640x352 (no detections), 41.2ms
# Speed: 1.1ms preprocess, 41.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 53
#
# 0: 640x352 (no detections), 42.9ms
# Speed: 1.1ms preprocess, 42.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 54
#
# 0: 640x352 (no detections), 41.2ms
# Speed: 1.1ms preprocess, 41.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 55
#
# 0: 640x352 (no detections), 44.7ms
# Speed: 1.1ms preprocess, 44.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 56
#
# 0: 640x352 (no detections), 44.5ms
# Speed: 1.3ms preprocess, 44.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 57
#
# 0: 640x352 (no detections), 42.5ms
# Speed: 1.5ms preprocess, 42.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 58
#
# 0: 640x352 (no detections), 44.8ms
# Speed: 1.4ms preprocess, 44.8ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 59
#
# 0: 640x352 (no detections), 43.1ms
# Speed: 1.1ms preprocess, 43.1ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 60
#
# 0: 640x352 (no detections), 42.8ms
# Speed: 1.2ms preprocess, 42.8ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 61
#
# 0: 640x352 (no detections), 43.2ms
# Speed: 1.2ms preprocess, 43.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 62
#
# 0: 640x352 (no detections), 45.7ms
# Speed: 1.7ms preprocess, 45.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 63
#
# 0: 640x352 (no detections), 42.1ms
# Speed: 1.1ms preprocess, 42.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 64
#
# 0: 640x352 (no detections), 43.6ms
# Speed: 1.1ms preprocess, 43.6ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 65
#
# 0: 640x352 (no detections), 44.1ms
# Speed: 1.1ms preprocess, 44.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 66
#
# 0: 640x352 (no detections), 44.6ms
# Speed: 1.2ms preprocess, 44.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 67
#
# 0: 640x352 (no detections), 41.1ms
# Speed: 1.4ms preprocess, 41.1ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 68
#
# 0: 640x352 1 drone, 44.8ms
# Speed: 1.3ms preprocess, 44.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 69
#
# 0: 640x352 1 drone, 44.2ms
# Speed: 1.1ms preprocess, 44.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 70
#
# 0: 640x352 1 drone, 41.9ms
# Speed: 1.3ms preprocess, 41.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 71
#
# 0: 640x352 1 drone, 46.5ms
# Speed: 1.2ms preprocess, 46.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 72
#
# 0: 640x352 1 drone, 42.3ms
# Speed: 1.2ms preprocess, 42.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 73
#
# 0: 640x352 1 drone, 45.0ms
# Speed: 1.1ms preprocess, 45.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 74
#
# 0: 640x352 1 drone, 43.7ms
# Speed: 1.1ms preprocess, 43.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 75
#
# 0: 640x352 1 drone, 41.3ms
# Speed: 1.1ms preprocess, 41.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 76
#
# 0: 640x352 1 drone, 48.8ms
# Speed: 1.4ms preprocess, 48.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 77
#
# 0: 640x352 1 drone, 41.4ms
# Speed: 1.2ms preprocess, 41.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 78
#
# 0: 640x352 1 drone, 45.4ms
# Speed: 1.1ms preprocess, 45.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 79
#
# 0: 640x352 1 drone, 42.9ms
# Speed: 1.3ms preprocess, 42.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 80
#
# 0: 640x352 1 drone, 43.0ms
# Speed: 1.1ms preprocess, 43.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 81
#
# 0: 640x352 1 drone, 45.4ms
# Speed: 1.1ms preprocess, 45.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 82
#
# 0: 640x352 1 drone, 42.0ms
# Speed: 1.2ms preprocess, 42.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 83
#
# 0: 640x352 1 drone, 43.6ms
# Speed: 1.2ms preprocess, 43.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 84
#
# 0: 640x352 1 drone, 47.0ms
# Speed: 1.4ms preprocess, 47.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 85
#
# 0: 640x352 1 drone, 42.4ms
# Speed: 1.2ms preprocess, 42.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 86
#
# 0: 640x352 1 drone, 43.9ms
# Speed: 1.1ms preprocess, 43.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 87
#
# 0: 640x352 1 drone, 43.6ms
# Speed: 1.1ms preprocess, 43.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 88
#
# 0: 640x352 1 drone, 43.2ms
# Speed: 1.1ms preprocess, 43.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 89
#
# 0: 640x352 1 drone, 41.9ms
# Speed: 1.1ms preprocess, 41.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 90
#
# 0: 640x352 1 drone, 42.9ms
# Speed: 1.2ms preprocess, 42.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 91
#
# 0: 640x352 1 drone, 42.5ms
# Speed: 1.2ms preprocess, 42.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 92
#
# 0: 640x352 1 drone, 44.3ms
# Speed: 1.1ms preprocess, 44.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 93
#
# 0: 640x352 1 drone, 43.4ms
# Speed: 1.3ms preprocess, 43.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 94
#
# 0: 640x352 1 drone, 42.3ms
# Speed: 1.2ms preprocess, 42.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 95
#
# 0: 640x352 1 drone, 46.1ms
# Speed: 1.3ms preprocess, 46.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 96
#
# 0: 640x352 1 drone, 41.9ms
# Speed: 1.2ms preprocess, 41.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 97
#
# 0: 640x352 1 drone, 42.2ms
# Speed: 1.3ms preprocess, 42.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 98
#
# 0: 640x352 1 drone, 44.8ms
# Speed: 1.1ms preprocess, 44.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 99
#
# 0: 640x352 1 drone, 42.4ms
# Speed: 1.1ms preprocess, 42.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 100
#
# 0: 640x352 1 drone, 43.6ms
# Speed: 1.2ms preprocess, 43.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 101
#
# 0: 640x352 1 drone, 43.0ms
# Speed: 1.7ms preprocess, 43.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 102
#
# 0: 640x352 1 drone, 43.9ms
# Speed: 1.1ms preprocess, 43.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 103
#
# 0: 640x352 1 drone, 43.4ms
# Speed: 1.1ms preprocess, 43.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 104
#
# 0: 640x352 1 drone, 42.1ms
# Speed: 1.2ms preprocess, 42.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 105
#
# 0: 640x352 1 drone, 44.1ms
# Speed: 1.6ms preprocess, 44.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame
 42.4ms
# Speed: 1.1ms preprocess, 42.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 195
#
# 0: 640x352 1 drone, 43.4ms
# Speed: 1.1ms preprocess, 43.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 196
#
# 0: 640x352 1 drone, 42.3ms
# Speed: 1.1ms preprocess, 42.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 197
#
# 0: 640x352 1 drone, 45.1ms
# Speed: 1.4ms preprocess, 45.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 198
#
# 0: 640x352 1 drone, 46.6ms
# Speed: 1.2ms preprocess, 46.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 199
#
# 0: 640x352 1 drone, 43.7ms
# Speed: 1.2ms preprocess, 43.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 200
#
# 0: 640x352 1 drone, 41.9ms
# Speed: 1.1ms preprocess, 41.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 201
#
# 0: 640x352 1 drone, 40.9ms
# Speed: 1.2ms preprocess, 40.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 202
#
# 0: 640x352 1 drone, 41.2ms
# Speed: 1.1ms preprocess, 41.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 203
#
# 0: 640x352 1 drone, 42.9ms
# Speed: 1.2ms preprocess, 42.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 204
#
# 0: 640x352 1 drone, 47.0ms
# Speed: 1.3ms preprocess, 47.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 205
#
# 0: 640x352 1 drone, 42.2ms
# Speed: 1.1ms preprocess, 42.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 206
#
# 0: 640x352 1 drone, 44.1ms
# Speed: 2.1ms preprocess, 44.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 207
#
# 0: 640x352 1 drone, 42.9ms
# Speed: 1.1ms preprocess, 42.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 208
#
# 0: 640x352 1 drone, 42.0ms
# Speed: 1.1ms preprocess, 42.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 209
#
# 0: 640x352 1 drone, 42.2ms
# Speed: 1.2ms preprocess, 42.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 210
#
# 0: 640x352 1 drone, 43.8ms
# Speed: 1.3ms preprocess, 43.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 211
#
# 0: 640x352 1 drone, 42.8ms
# Speed: 1.1ms preprocess, 42.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 212
#
# 0: 640x352 1 drone, 43.5ms
# Speed: 1.1ms preprocess, 43.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 213
#
# 0: 640x352 1 drone, 41.8ms
# Speed: 1.1ms preprocess, 41.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 214
#
# 0: 640x352 1 drone, 44.0ms
# Speed: 1.1ms preprocess, 44.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 215
#
# 0: 640x352 1 drone, 54.0ms
# Speed: 1.3ms preprocess, 54.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 216
#
# 0: 640x352 1 drone, 53.6ms
# Speed: 1.6ms preprocess, 53.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 217
#
# 0: 640x352 1 drone, 43.1ms
# Speed: 1.2ms preprocess, 43.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 218
#
# 0: 640x352 1 drone, 41.6ms
# Speed: 1.1ms preprocess, 41.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 219
#
# 0: 640x352 1 drone, 41.2ms
# Speed: 1.4ms preprocess, 41.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 220
#
# 0: 640x352 1 drone, 42.2ms
# Speed: 1.3ms preprocess, 42.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 221
#
# 0: 640x352 1 drone, 42.7ms
# Speed: 1.4ms preprocess, 42.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 222
#
# 0: 640x352 1 drone, 43.8ms
# Speed: 1.1ms preprocess, 43.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 223
#
# 0: 640x352 1 drone, 42.8ms
# Speed: 1.1ms preprocess, 42.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 224
#
# 0: 640x352 1 drone, 43.9ms
# Speed: 1.3ms preprocess, 43.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 225
#
# 0: 640x352 1 drone, 43.2ms
# Speed: 1.2ms preprocess, 43.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 226
#
# 0: 640x352 1 drone, 43.5ms
# Speed: 1.2ms preprocess, 43.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 227
#
# 0: 640x352 1 drone, 42.9ms
# Speed: 1.1ms preprocess, 42.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 228
#
# 0: 640x352 1 drone, 44.0ms
# Speed: 1.1ms preprocess, 44.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 229
#
# 0: 640x352 1 drone, 44.6ms
# Speed: 1.1ms preprocess, 44.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 230
#
# 0: 640x352 1 drone, 41.9ms
# Speed: 1.2ms preprocess, 41.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 231
#
# 0: 640x352 1 drone, 42.7ms
# Speed: 1.2ms preprocess, 42.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 232
#
# 0: 640x352 1 drone, 41.6ms
# Speed: 1.1ms preprocess, 41.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 233
#
# 0: 640x352 1 drone, 44.4ms
# Speed: 1.1ms preprocess, 44.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 234
#
# 0: 640x352 1 drone, 43.5ms
# Speed: 1.3ms preprocess, 43.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 235
#
# 0: 640x352 1 drone, 43.3ms
# Speed: 1.2ms preprocess, 43.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 236
#
# 0: 640x352 1 drone, 42.5ms
# Speed: 1.1ms preprocess, 42.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 237
#
# 0: 640x352 1 drone, 43.1ms
# Speed: 1.1ms preprocess, 43.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 238
#
# 0: 640x352 1 drone, 43.6ms
# Speed: 1.2ms preprocess, 43.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 239
#
# 0: 640x352 1 drone, 41.7ms
# Speed: 1.4ms preprocess, 41.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 240
#
# 0: 640x352 1 drone, 42.8ms
# Speed: 1.3ms preprocess, 42.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 241
#
# 0: 640x352 1 drone, 42.0ms
# Speed: 1.1ms preprocess, 42.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 242
#
# 0: 640x352 1 drone, 41.8ms
# Speed: 1.1ms preprocess, 41.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 243
#
# 0: 640x352 1 drone, 47.0ms
# Speed: 1.2ms preprocess, 47.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 244
#
# 0: 640x352 1 drone, 43.4ms
# Speed: 1.5ms preprocess, 43.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 245
#
# 0: 640x352 1 drone, 42.0ms
# Speed: 1.1ms preprocess, 42.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 246
#
# 0: 640x352 1 drone, 43.8ms
# Speed: 1.3ms preprocess, 43.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 247
#
# 0: 640x352 (no detections), 45.1ms
# Speed: 2.1ms preprocess, 45.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 248
#
# 0: 640x352 (no detections), 43.6ms
# Speed: 1.3ms preprocess, 43.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 249
#
# 0: 640x352 (no detections), 46.1ms
# Speed: 1.3ms preprocess, 46.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 250
#
# 0: 640x352 (no detections), 55.7ms
# Speed: 1.1ms preprocess, 55.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 251
#
# 0: 640x352 (no detections), 49.5ms
# Speed: 1.8ms preprocess, 49.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 252
#
# 0: 640x352 (no detections), 43.9ms
# Speed: 1.4ms preprocess, 43.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 253
#
# 0: 640x352 1 drone, 41.9ms
# Speed: 1.2ms preprocess, 41.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 254
#
# 0: 640x352 1 drone, 46.8ms
# Speed: 1.3ms preprocess, 46.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 255
#
# 0: 640x352 1 drone, 45.8ms
# Speed: 1.1ms preprocess, 45.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 256
#
# 0: 640x352 (no detections), 44.5ms
# Speed: 1.1ms preprocess, 44.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 257
#
# 0: 640x352 (no detections), 42.5ms
# Speed: 1.2ms preprocess, 42.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 258
#
# 0: 640x352 (no detections), 53.4ms
# Speed: 1.5ms preprocess, 53.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 259
#
# 0: 640x352 (no detections), 41.3ms
# Speed: 1.2ms preprocess, 41.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 260
#
# 0: 640x352 (no detections), 44.1ms
# Speed: 1.1ms preprocess, 44.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 261
#
# 0: 640x352 (no detections), 44.1ms
# Speed: 1.1ms preprocess, 44.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 262
#
# 0: 640x352 (no detections), 41.5ms
# Speed: 1.1ms preprocess, 41.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 263
#
# 0: 640x352 (no detections), 42.2ms
# Speed: 1.2ms preprocess, 42.2ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 264
#
# 0: 640x352 (no detections), 48.3ms
# Speed: 1.2ms preprocess, 48.3ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 265
#
# 0: 640x352 (no detections), 43.6ms
# Speed: 1.4ms preprocess, 43.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 266
#
# 0: 640x352 (no detections), 42.3ms
# Speed: 1.1ms preprocess, 42.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 267
#
# 0: 640x352 (no detections), 42.6ms
# Speed: 1.1ms preprocess, 42.6ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 268
#
# 0: 640x352 (no detections), 42.0ms
# Speed: 1.1ms preprocess, 42.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 269
#
# 0: 640x352 (no detections), 42.9ms
# Speed: 1.1ms preprocess, 42.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 270
#
# 0: 640x352 (no detections), 44.4ms
# Speed: 1.1ms preprocess, 44.4ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 271
#
# 0: 640x352 (no detections), 42.2ms
# Speed: 1.1ms preprocess, 42.2ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 352)
# Processed frame 272
